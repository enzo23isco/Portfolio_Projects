# %% [markdown]
# # Statsbomb Free Data
# ### Documentation https://github.com/statsbomb/statsbombpy/tree/master

# %%
from statsbombpy import sb

# %%
df = sb.matches(competition_id=16, season_id=22)
df
# Out:
# /Users/enzovillafuerte/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                competition     season  \
# 0     18236  2011-05-28  20:45:00.000  Europe - Champions League  2010/2011
#
#    home_team          away_team  home_score  away_score match_status  ...  \
# 0  Barcelona  Manchester United           3           1    available  ...
#
#           last_updated_360 match_week competition_stage          stadium  \
# 0  2021-06-13T16:17:31.694          1             Final  Wembley Stadium
#
#          referee           home_managers  away_managers data_version  \
# 0  Viktor Kassai  Josep Guardiola i Sala  Alex Ferguson        1.0.3
#
#   shot_fidelity_version xy_fidelity_version
# 0                  None                None
#
# [1 rows x 22 columns]

# %%
sb.matches(competition_id=11, season_id=22)
# Out:
# /Users/enzovillafuerte/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off      competition     season  \
# 0      69276  2011-02-05  22:00:00.000  Spain - La Liga  2010/2011
# 1      69304  2011-04-02  22:00:00.000  Spain - La Liga  2010/2011
# 2      69307  2010-12-04  20:45:00.000  Spain - La Liga  2010/2011
# 3      69271  2011-04-23  20:00:00.000  Spain - La Liga  2010/2011
# 4      69305  2011-04-09  20:00:00.000  Spain - La Liga  2010/2011
# 5      69278  2011-01-16  21:00:00.000  Spain - La Liga  2010/2011
# 6      69275  2010-12-18  20:00:00.000  Spain - La Liga  2010/2011
# 7      69295  2011-01-22  20:00:00.000  Spain - La Liga  2010/2011
# 8      69270  2010-11-07  19:00:00.000  Spain - La Liga  2010/2011
# 9      69303  2011-03-19  20:00:00.000  Spain - La Liga  2010/2011
# ...

# %%
events = sb.events(match_id=69276)
events.columns
# Out:
# /Users/enzovillafuerte/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Index(['bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive',
#        'block_save_block', 'carry_end_location', 'clearance_aerial_won',
#        'clearance_body_part', 'clearance_head', 'clearance_left_foot',
#        'clearance_right_foot', 'counterpress', 'dribble_nutmeg',
#        'dribble_outcome', 'dribble_overrun', 'duel_outcome', 'duel_type',
#        'duration', 'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
# ...

# %%
events = events[events.pass_end_location.isnull()==False]

# %%
events.to_csv('BarcavsManUtd2011.csv', index=None)

# %%
import pandas as pd

pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)  

data = pd.read_csv(
